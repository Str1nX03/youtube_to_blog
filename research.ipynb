# %%
from src.agents.youtube_analyzer import YoutubeAnalyzeAgent

youtube_url = "https://youtu.be/qrREzsRq2Jg?si=o2k_4QblNDdc859X"
youtube_summary = YoutubeAnalyzeAgent()

print(youtube_summary.analyze(youtube_url))
# Out:
# **Structured Summary**
#
# **1. Main Topic:**
# The main topic of the video is the analysis of the 2026 Candidates Tournament in chess, specifically the tier list ranking of the eight players participating in the tournament.
#
# **2. Key Points:**
#
# * The 2026 Candidates Tournament is an eight-player double round-robin tournament, with the winner moving on to challenge for the world chess championship.
# * The tournament features a diverse field of players from different countries and generations.
# * The analyst creates a tier list ranking the players into five categories: clear favorites, unexpected but not shocking, unlikely to win, unlikely to be last, and maybe hoping for an upset or two.
# * The analyst discusses each player's strengths and weaknesses, including their experience, rating, and head-to-head scores against other players.
# ...

# %%
from src.agents.researcher import ResearchAgent

enriched_content = ResearchAgent()

print(enriched_content.enrich_context(video_analysis = youtube_summary))
# Out:
# g:\Dravin\Projects\youtube_to_blog\src\agents\researcher.py:24: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# g:\Dravin\Projects\youtube_to_blog\src\agents\researcher.py:24: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# g:\Dravin\Projects\youtube_to_blog\src\agents\researcher.py:24: RuntimeWarning: This package (`duckduckgo_search`) has been renamed to `ddgs`! Use `pip install ddgs` instead.
#   with DDGS() as ddgs:
# External Research Findings:
# Title: International Chess Federation – International Chess Federation ...
# Link: https://www.fide.com/
# Snippet: No part of this site may be reproduced, stored in a retrieval system or transmitted in any way or by any means (including photocopying, recording or storing it in any medium by electronic means), without …
#
# Title: FIDE - Wikipedia
# ...
