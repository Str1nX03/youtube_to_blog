# %%
from src.agents.youtube_analyzer import YoutubeAnalyzeAgent

youtube_url = "https://youtu.be/qrREzsRq2Jg?si=o2k_4QblNDdc859X"
agent = YoutubeAnalyzeAgent()

print(agent.analyze(youtube_url))
# Out:
# **Structured Summary**
#
# **1. Main Topic:**
# The main topic of the video is the analysis of the 2026 Candidates Tournament in chess, specifically the tier list of the eight players participating in the tournament.
#
# **2. Key Points:**
#
# * The 2026 Candidates Tournament is an eight-player double round-robin tournament, with the winner moving on to challenge for the world chess championship.
# * The tournament features a diverse field of players from different countries and generations.
# * The analyst creates a tier list to categorize the players based on their chances of winning the tournament.
# * The tier list categories are:
# 	+ Clear favorites
# 	+ Unexpected but not shocking
# 	+ Unlikely to win
# 	+ Unlikely to be last
# 	+ Maybe hoping for an upset or two
# 	+ Only here for experience
# * The analyst analyzes each player's strengths and weaknesses, including their ratings, past performances, and head-to-head records against other players.
# * The players analyzed are:
# 	+ Matias Bluebomb (Germany)
# 	+ Javahir Sundarov (Usbekistan)
# 	+ Anish Giri (Netherlands)
# 	+ Andre Yasipenko (Russia)
# 	+ Fabiano Caruana (United States)
# 	+ Hikaru Nakamura (United States)
# 	+ Pragnananda Ramos Babu (India)
# 	+ Wei Yi (China)
#
# **3. The tone of the video:**
# The tone of the video is informative, analytical, and slightly humorous. The analyst provides a detailed and objective analysis of each player's chances, while also injecting some personality and humor into the commentary.
#
# **4. Important keywords:**
# * Chess
# * Candidates Tournament
# * Tier list
# * Chess ratings
# * Head-to-head records
# * Chess strategy
# * Chess analysis
# * Chess players
# * Chess tournaments
