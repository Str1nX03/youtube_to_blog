# %%
from src.agents.youtube_analyzer import YoutubeAnalyzeAgent

youtube_url = "https://youtu.be/CkZVk-H0U2s?si=5XMwFvWIE-pO5vlp"
Youtube_Agent = YoutubeAnalyzeAgent()

summary = Youtube_Agent.analyze(youtube_url)
# Out:
# [download] Got error: HTTP Error 403: Forbidden
# [download] Got error: HTTP Error 403: Forbidden
# [download] Got error: HTTP Error 403: Forbidden

# %%
print(summary)
# Out:
# **Structured Summary**
#
# **1. Main Topic:**
# The main topic of the video is a list of 20 challenging games that are considered "hard" and "punishing" in the Souls-like genre. The host discusses the unique features and mechanics that make each game difficult, and provides an analysis of what makes them so challenging.
#
# **2. Key Points:**
#
# * The host argues that modern gamers have become too soft and expect easy modes, but these games are designed to be challenging and rewarding.
# * The list includes games such as Mortal Shell, Hellpoint, Celeste, Wolong Fallen Dynasty, Blasphemous One and Two, Black Myth Wukong, The First Berserker: Kazan, Hollow Knight, Silk Song, Lies of P, and the Dark Souls series.
# * Each game has unique mechanics and features that make them difficult, such as punishing platforming, Souls-like combat, and trial-and-error design.
# * The host highlights the importance of skill and patience in overcoming the challenges of these games.
# ...

# %%
summary = """

**Structured Summary**

**1. Main Topic:**
The main topic of the video is a list of 20 challenging games that are considered "hard" and "punishing" in the Souls-like genre. The host discusses the unique features and mechanics that make each game difficult, and provides an analysis of what makes them so challenging.

**2. Key Points:**

* The host argues that modern gamers have become too soft and expect easy modes, but these games are designed to be challenging and rewarding.
* The list includes games such as Mortal Shell, Hellpoint, Celeste, Wolong Fallen Dynasty, Blasphemous One and Two, Black Myth Wukong, The First Berserker: Kazan, Hollow Knight, Silk Song, Lies of P, and the Dark Souls series.
* Each game has unique mechanics and features that make them difficult, such as punishing platforming, Souls-like combat, and trial-and-error design.
* The host highlights the importance of skill and patience in overcoming the challenges of these games.
* Some games, such as Celeste and Lies of P, have assist modes or features that make them more accessible, but the standard experience is still challenging.
* The host notes that the difficulty spikes in some games, such as Silk Song, can be a rude awakening for players who have become rusty.

**3. Tone of the video:**
The tone of the video is informative, analytical, and slightly sarcastic. The host has a dry sense of humor and often uses irony to make a point. The tone is also enthusiastic and passionate, as the host clearly enjoys discussing and playing these challenging games.

**4. Important keywords:**

* Souls-like games
* Challenging games
* Punishing platforming
* Trial-and-error design
* Skill and patience
* Difficulty spikes
* Dark Souls series
* Lies of P
* Celeste
* Mortal Shell
* Hellpoint
* Wolong Fallen Dynasty
* Blasphemous One and Two
* Black Myth Wukong
* The First Berserker: Kazan
* Hollow Knight
* Silk Song

"""

# %%
from src.agents.researcher import ResearchAgent

Research_Agent = ResearchAgent()

content = Research_Agent.enrich_context(video_analysis = summary)

# %%
print(content)
# Out:
# External Research Findings:
# Title: The Best Action / Adventure Game of 2024
# Link: https://sea.ign.com/black-myth-wukong/223483/feature/the-best-action-adventure-game-of-2024
# Snippet: It’s this that allows Black Myth: Wukong to feel like something of a new, exciting frontier: while its gameplay may be Souls -ish and its gear ...
#
# Title: The Best PlayStation Game of 2024
# Link: https://sea.ign.com/astro-bot/223490/feature/the-best-playstation-game-of-2024
# Snippet: What could have felt like a soulless brand exercise is instead perhaps the most engaging collectathon of the generation, with a constantly mounting ...
#
# Title: Our 16 Favorite Games from PAX East 2024
# Link: https://me.ign.com/en/pc/219616/preview/our-16-favorite-games-from-pax-east-2024
# Snippet: I grew up playing games like Turtles ... The second was that the combat felt both weighty and satisfying, unlike some games in the Souls - like genre.
#
# ...

# %%
content = """

External Research Findings:
Title: The Best Action / Adventure Game of 2024
Link: https://sea.ign.com/black-myth-wukong/223483/feature/the-best-action-adventure-game-of-2024
Snippet: It’s this that allows Black Myth: Wukong to feel like something of a new, exciting frontier: while its gameplay may be Souls -ish and its gear ...

Title: The Best PlayStation Game of 2024
Link: https://sea.ign.com/astro-bot/223490/feature/the-best-playstation-game-of-2024
Snippet: What could have felt like a soulless brand exercise is instead perhaps the most engaging collectathon of the generation, with a constantly mounting ...

Title: Our 16 Favorite Games from PAX East 2024
Link: https://me.ign.com/en/pc/219616/preview/our-16-favorite-games-from-pax-east-2024
Snippet: I grew up playing games like Turtles ... The second was that the combat felt both weighty and satisfying, unlike some games in the Souls - like genre.

Title: Platformer Game Design (Definition, Fundamentals, Mechanics)
Link: https://gamedesignskills.com/game-design/platformer/
Snippet: October 29, 2025 - More punishing games space out the checkpoints so multiple scenarios occur between getting them or make it possible to even lose them . The Silksong checkpoint system has been criticized for long boss runbacks, where the player must spend extra ...

Title: r/truegaming on Reddit: Should games mechanically punish players for losing?
Link: https://www.reddit.com/r/truegaming/comments/snqa71/should_games_mechanically_punish_players_for/
Snippet: February 24, 2021 - In Celeste, when you die you just get sent back to the beginning of the room, because in a reflex-based platformer you want that immediate feedback and the ability to try the challenge again right away. Now imagine if you did that in Hades - you die and immediately it resets to the beginning of the room, you get all your health back, and you get to try again. It would defeat the entire purpose of the game being this Sisyphean task of hitting your head against a wall until you finally break through. ... Yep. Different mechanics for different games.

Title: Challenging versus Punishing in video games – Crider the Writer
Link: https://drewcrider.com/2016/04/09/challenging-versus-punishing-in-video-games/
Snippet: April 9, 2016 - This feature is common to many, many games, of course, and platforming games in particular have the player replaying long segments because they died somewhere along the line. But Rayman Origins doesn’t have this problem; in that game, when your character dies in a room, they simply return to the beginning of the room, usually losing just a few seconds of gameplay. Rayman Origins doesn’t want to punish you for failing; it wants you to keep playing the game.

Title: Game difficulty spikes history: extreme challenges that marked games.
Link: https://fact2day.com/game-difficulty-spikes-history/
Snippet: Game difficulty spikes history refers to moments in video games where the challenge unexpectedly increases, testing player skills and patience while influencing game design and player engagement.

Title: 2024 Hardest Games - Brutal Titles That Test Gamers
Link: https://www.blackmythwukongtalk.com/articles/the-10-hardest-games-of-2024-that-tested-players-sanity.html
Snippet: The 10 Hardest Games of 2024 That Tested Players' Sanity Discover 2024's most challenging games like Hades 2 and Sons of the Forest, offering relentless difficulty and adrenaline-pumping survival experiences.

Title: Hardest Games of 2024 - DualShockers
Link: https://www.dualshockers.com/hardest-games-of-2024/
Snippet: If you love testing both your patience and sanity at the same time, you'll want to take a peek at these hardest games of 2024 !

"""

# %%
from src.agents.blogger import BloggerAgent

Blogging_Agent = BloggerAgent()

blog = Blogging_Agent.write_blog(video_analysis = summary, research_findings = content)

# %%
print(blog)
# Out:
# **The Ultimate Challenge: 20 Souls-like Games That Will Put Your Skills to the Test**
#
# Are you ready to face your fears and push your gaming skills to the limit? Look no further! In this article, we'll explore the world of Souls-like games, a genre that's all about challenging gameplay, punishing difficulty, and rewarding triumphs. From the Dark Souls series to newer titles like Black Myth: Wukong, we'll dive into the top 20 games that will put your skills to the test.
#
# **The Evolution of Challenging Games**
#
# ...

# %%
blog = """

**The Ultimate Challenge: 20 Souls-like Games That Will Put Your Skills to the Test**

