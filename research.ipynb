# %%
from src.agents.youtube_analyzer import YoutubeAnalyzeAgent

youtube_url = "https://youtu.be/CkZVk-H0U2s?si=5XMwFvWIE-pO5vlp"
youtube_summary = YoutubeAnalyzeAgent()

summary = youtube_summary.analyze(youtube_url)
# Out:
# [download] Got error: HTTP Error 403: Forbidden
# [download] Got error: HTTP Error 403: Forbidden
# [download] Got error: HTTP Error 403: Forbidden

# %%
summary = """

**Structured Summary**

**1. Main Topic:**
The main topic of the video is a list of 20 challenging games that are considered "hard" or "punishing" in the Souls-like genre. The host discusses the unique features and mechanics of each game that make them difficult to play.

**2. Key Points:**

* The host argues that modern gamers have become "soft" and expect easy modes, but these games are designed to challenge players and require skill and patience.
* The list includes games such as Mortal Shell, Hellpoint, Celeste, Wolong Fallen Dynasty, Blasphemous One and Two, Black Myth Wukong, The First Berserker: Kazan, Hollow Knight, and Lies of P.
* Each game has unique mechanics and features that make them difficult to play, such as punishing difficulty spikes, tight timing windows, and complex combat systems.
* The host praises the games for their challenging gameplay and rewards players for mastering their mechanics.
* The list also includes the Dark Souls series, which is considered the originator of the Souls-like genre.

**3. Tone of the video:**
The tone of the video is enthusiastic and encouraging, with the host praising the games for their challenging gameplay and rewarding players for mastering their mechanics. The host also acknowledges that the games can be frustrating at times, but argues that this is a necessary part of the learning process.

**4. Important keywords:**
* Souls-like games
* Challenging gameplay
* Punishing difficulty spikes
* Tight timing windows
* Complex combat systems
* Dark Souls series
* Mortal Shell
* Hellpoint
* Celeste
* Wolong Fallen Dynasty
* Blasphemous One and Two
* Black Myth Wukong
* The First Berserker: Kazan
* Hollow Knight
* Lies of P

"""

# %%
from src.agents.researcher import ResearchAgent

enriched_content = ResearchAgent()

content = enriched_content.enrich_context(video_analysis = summary)

# %%
print(content)
# Out:
# External Research Findings:
# Title: 14. Mortal Shell. Souls-like Games Rated Easiest to Hardest - gamepressure.com
# Link: https://www.gamepressure.com/editorials/souls-like-games-rated-easiest-to-hardest/13-code-vein/z73ca
# Snippet: July 19, 2024 - The general evaluation of Mortal ... inspiration. I can agree. The game is more accessible, and probably only the idiosyncratic combat system increases the difficulty ......
#
# Title: The Hardest Dark Souls And Souls-Like Games, Ranked
# Link: https://www.thegamer.com/dark-souls-souls-like-hardest-games-ranked/
# Snippet: April 1, 2024 - The atmosphere is bleak, the enemy designs are grotesque, and the difficulty is high. You'll die a lot, but isn't that why you play souls-likes? ... The original Souls game. Demon's Souls was the original punishing game with methodical exploration that was made by FromSoftware.
#
# Title: What are the Best 2D Soulslike Games Ever Released?
# Link: https://hardcoregamer.com/best-2d-soulslike-games/
# ...
